# %% [markdown]
# # Multi label classification with Bert
# Use oversampling with the same model to increase accuracy

# %%
# Import all libraries
import pandas as pd
import numpy as np
import re

# Huggingface transformers
import transformers
from transformers import BertModel,BertTokenizer,AdamW, get_linear_schedule_with_warmup

import torch
from torch import nn ,cuda
from torch.utils.data import DataLoader,Dataset,RandomSampler, SequentialSampler

import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

#handling html data
from bs4 import BeautifulSoup

import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

BERT_MODEL_NAME = 'bert-base-cased'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
import TextCleaner

# %% [markdown]
# # Load dataset

# %%
topics = [
    "sortings",
    "strings",
    "greedy",
    "number theory",
    "math",
    "graphs",
    "geometry",
    "data structures",
]

topics
# Out:
# ['sortings',
#  'strings',
#  'greedy',
#  'number theory',
#  'math',
#  'graphs',
#  'geometry',
#  'data structures']

# %%
import json 

problems = []
for topic in topics:
  codeforcesProblems = json.load(open(f"data/codeforces-{topic}.json"))
  problems.extend(codeforcesProblems)
  # omegaupProblems = json.load(open(f"data/omegaup-{topic}.json"))
  # problems.extend(omegaupProblems)

data = []
for problem in problems:
    validTopics = [topic for topic in problem['topics'] if topic in topics]
    text = problem['history']

    data.append({
      'title': problem['title'],
      'history': TextCleaner.pretty(text) if len(text) else "",
      'topics': validTopics,
      'url': problem['url'],
    })

# %%
df = pd.DataFrame(data)
df
# Out:
#                                  title  \
# 0               Yet Another Tournament
# 1                    Make it Beautiful
# 2                    Equal Frequencies
# 3                  Going to the Cinema
# 4       Anya's Simultaneous Exhibition
# ...                                ...
# 7737                              Ball
# 7738                        Exposition
# 7739               Bindian Signalizing
# 7740  Longest Regular Bracket Sequence
# 7741               Registration System
#
#                                                 history  \
# 0     You are participating in Yet Another Tournamen...
# 1     An array a is called ugly if it contains at le...
# 2     Let' s call a string balanced if all character...
# 3     A company of n people is planning a visit to t...
# 4     This is an interactive problem. Anya has gathe...
# ...                                                 ...
# 7737  N ladies attend the ball in the King' s palace...
# 7738  There are several days left before the fiftiet...
# 7739  Everyone knows that long ago on the territory ...
# 7740  This is yet another problem dealing with regul...
# 7741  A new e- mail service " Berlandesk" is going t...
#
#                                             topics  \
# 0                               [greedy, sortings]
# 1                                 [math, sortings]
# 2                      [greedy, sortings, strings]
# 3                               [greedy, sortings]
# 4                       [graphs, greedy, sortings]
# ...                                            ...
# 7737                   [data structures, sortings]
# 7738                             [data structures]
# 7739                             [data structures]
# 7740  [data structures, greedy, sortings, strings]
# 7741                             [data structures]
#
#                                                    url
# 0     https://codeforces.com/problemset/problem/1783/C
# 1     https://codeforces.com/problemset/problem/1783/A
# 2     https://codeforces.com/problemset/problem/1781/C
# 3     https://codeforces.com/problemset/problem/1781/B
# 4     https://codeforces.com/problemset/problem/1779/E
# ...                                                ...
# 7737    https://codeforces.com/problemset/problem/12/D
# 7738     https://codeforces.com/problemset/problem/6/E
# 7739     https://codeforces.com/problemset/problem/5/E
# 7740     https://codeforces.com/problemset/problem/5/C
# 7741     https://codeforces.com/problemset/problem/4/C
#
# [7742 rows x 4 columns]

# %%
df.shape
# Out:
# (7742, 4)

# %%
df['history'] = df['history'].apply(lambda x: x.replace('\t', '').replace('\n', '').replace('\"', ''))

# %%
dfclean = df[['title', 'history', 'topics', 'url']]

# %%
dfclean.to_csv("data/codeforces.csv")

# %%
result = dfclean.to_json(orient="records")
parsed = json.loads(result)
with open('data/codeforces.json', 'w') as f:
  json.dump(parsed, f, indent=2)

# %%
df2 = pd.read_csv("data/codeforces.csv")
df2
# Out:
#       Unnamed: 0                             title  \
# 0              0            Yet Another Tournament
# 1              1                 Make it Beautiful
# 2              2                 Equal Frequencies
# 3              3               Going to the Cinema
# 4              4    Anya's Simultaneous Exhibition
# ...          ...                               ...
# 7737        7737                              Ball
# 7738        7738                        Exposition
# 7739        7739               Bindian Signalizing
# 7740        7740  Longest Regular Bracket Sequence
# 7741        7741               Registration System
#
#                                                 history  \
# 0     You are participating in Yet Another Tournamen...
# 1     An array a is called ugly if it contains at le...
# 2     Let' s call a string balanced if all character...
# 3     A company of n people is planning a visit to t...
# 4     This is an interactive problem. Anya has gathe...
# ...                                                 ...
# 7737  N ladies attend the ball in the King' s palace...
# 7738  There are several days left before the fiftiet...
# 7739  Everyone knows that long ago on the territory ...
# 7740  This is yet another problem dealing with regul...
# 7741  A new e- mail service  Berlandesk is going to ...
#
#                                                  topics  \
# 0                                ['greedy', 'sortings']
# 1                                  ['math', 'sortings']
# 2                     ['greedy', 'sortings', 'strings']
# 3                                ['greedy', 'sortings']
# 4                      ['graphs', 'greedy', 'sortings']
# ...                                                 ...
# 7737                    ['data structures', 'sortings']
# 7738                                ['data structures']
# 7739                                ['data structures']
# 7740  ['data structures', 'greedy', 'sortings', 'str...
# 7741                                ['data structures']
#
#                                                    url
# 0     https://codeforces.com/problemset/problem/1783/C
# 1     https://codeforces.com/problemset/problem/1783/A
# 2     https://codeforces.com/problemset/problem/1781/C
# 3     https://codeforces.com/problemset/problem/1781/B
# 4     https://codeforces.com/problemset/problem/1779/E
# ...                                                ...
# 7737    https://codeforces.com/problemset/problem/12/D
# 7738     https://codeforces.com/problemset/problem/6/E
# 7739     https://codeforces.com/problemset/problem/5/E
# 7740     https://codeforces.com/problemset/problem/5/C
# 7741     https://codeforces.com/problemset/problem/4/C
#
# [7742 rows x 5 columns]
